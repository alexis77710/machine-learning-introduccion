# %%
# hacer un programa que diga si una persona es mayor o menor de 18 años

# %%
persona1 = int(input("ingrese una edad"))

if persona1<18:
    print("persona1 es menor de 18 años")
else:
    print("persona1 es mayor de 18 años")
# Out:
# ingrese una edad 18
# persona1 es mayor de 18 años

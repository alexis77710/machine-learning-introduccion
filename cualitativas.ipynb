# %% [markdown]
# ![Logo ITQ](img/imagen1.png)
#
# **Nombre:** Alexis Arcos
# <br>
# **Fecha:** 30/03/2026
#
# ![Logo Python](img/imagen2.png)

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Master' 'Secundaria' 'Secundaria' 'Grado' 'Master' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Doctorado' 'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Grado' 'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Doctorado' 'Master'
#  'Bachillerato' 'Master' 'Grado' 'Master' 'Grado' 'Master' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Master' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Grado' 'Grado' 'Master' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Master' 'Secundaria' 'Doctorado' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Doctorado' 'Bachillerato' 'Master'
#  'Master' 'Grado' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Master' 'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Secundaria' 'Grado'
#  'Doctorado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Doctorado' 'Grado' 'Doctorado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Master' 'Secundaria'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Master'
#  'Secundaria' 'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Master' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Master'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Master'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Master' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Grado' 'Grado' 'Master' 'Doctorado' 'Doctorado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Doctorado' 'Secundaria' 'Grado' 'Secundaria'
#  'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Master' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Doctorado' 'Grado' 'Master' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Grado' 'Master']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información

# %%
import pandas as pd

## datos 
datos = (['Secundaria'] *110 + ['Bachillerato'] *172 + ['Grado'] *145 + ['Master'] *52 + ['Doctorado'] *21)

##crear data frame
df = pd.DataFrame(datos, columns=['Nivel_Estudios'])

# para utilizar datos ramdom 
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
# Ver las primeras filas
df.head()
##print(datos)
# Out:
#   Nivel_Estudios
# 0          Grado
# 1     Secundaria
# 2          Grado
# 3   Bachillerato
# 4     Secundaria

# %%
# Generar tabla de frecuencias
tabla_frecuencias = df['Nivel_Estudios'].value_counts().to_frame('Frecuencia_Absoluta')

#  frecuencia relativa 
tabla_frecuencias['Porcentaje'] = (df['Nivel_Estudios'].value_counts(normalize=True) * 100).round(2)

print("Resumen Estadístico de Variables Cualitativas:")
display(tabla_frecuencias)
# Out:
# Resumen Estadístico de Variables Cualitativas:
#                 Frecuencia_Absoluta  Porcentaje
# Nivel_Estudios
# Bachillerato                    172        34.4
# Grado                           145        29.0
# Secundaria                      110        22.0
# Master                           52        10.4
# Doctorado                        21         4.2

# %%
plt.style.use('ggplot')
# Graficar
ax = tabla_frecuencias['Frecuencia_Absoluta'].plot(kind='bar', 
                                                   figsize=(10, 5), 
                                                   color='skyblue', 
                                                   edgecolor='black')

plt.title('Distribución de Niveles de Estudio')
plt.xlabel('Grado Académico')
plt.ylabel('Cantidad de Personas')
plt.xticks(rotation=45)
plt.show()

# %%
# Pastel
tabla_frecuencias['Frecuencia_Absoluta'].plot(kind='pie', 
                                              figsize=(8, 8), 
                                              autopct='%1.2f%%', 
                                              startangle=90,
                                              cmap='Pastel1')

plt.title('Proporción por Nivel Educativo')

plt.show()

# %% [markdown]
# https://github.com/alexis77710/machine-learning-introduccion.git

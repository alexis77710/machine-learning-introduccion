# %% [markdown]
# ![Logo ITQ](img/imagen1.png)
#
# **Nombre:** Alexis Arcos
# <br>
# **Fecha:** 07/01/2026
#
# ![Logo Python](img/imagen2.png)

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# # Operaciones en pandas

# %% [markdown]
# #### Búsqueda

# %%
rand_matrix = np.random.randint(6,size=(2,3))
frame = pd.DataFrame(rand_matrix , columns=list('ABC'))
display(frame)
# Out:
#    A  B  C
# 0  3  2  3
# 1  3  4  5

# %%
# buscando columnas (DataFrame como dic, busca en claves)
'A' in frame
# Out:
# True

# %%
# buscando valores
display(frame.isin([3,2])) # --> mask de respuesta (valores que son 3 o 2)
# Out:
#       A      B      C
# 0  True   True   True
# 1  True  False  False

# %%
# Contar el número de ocurrencias
print(frame.isin([4]).values.sum())
display(frame.isin([4])) #devuelve una mask con valores true si el elemento es 4
print(frame.isin([4]).values)
type(frame.isin([4]).values) # pandas es una capa alrededor de numpy
# Out:
# 1
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# [[False False False]
#  [False  True False]]
# numpy.ndarray

# %%
# Cuántos valores son >= 2
mask = frame >= 2
print(mask.values.sum())
display(mask)
# Out:
# 6
#       A     B     C
# 0  True  True  True
# 1  True  True  True

# %% [markdown]
# #### Ordenación

# %%
from random import shuffle

rand_matrix = np.random.randint(20,size=(5,4))

indices = list(range(5))
shuffle(indices) # mezcla indices

frame = pd.DataFrame(rand_matrix , columns=list('DACB'), index=indices)
display(frame)
# Out:
#     D   A   C   B
# 1   3  17  19   8
# 3   5   0   1   6
# 4  17   4   0  19
# 2  13  17   0   5
# 0  18  13   0  11

# %%
# ordenar por índice
display(frame.sort_index(ascending=False))
display(frame)
# Out:
#     D   A   C   B
# 4  17   4   0  19
# 3   5   0   1   6
# 2  13  17   0   5
# 1   3  17  19   8
# 0  18  13   0  11
#     D   A   C   B
# 1   3  17  19   8
# 3   5   0   1   6
# 4  17   4   0  19
# 2  13  17   0   5
# 0  18  13   0  11

# %%
#ordenar por columna
display(frame.sort_index(axis=1, ascending=False))
# Out:
#     D   C   B   A
# 1   3  19   8  17
# 3   5   1   6   0
# 4  17   0  19   4
# 2  13   0   5  17
# 0  18   0  11  13

# %%
# ordenar filas por valor en columna
display(frame.sort_values(by='A', ascending=True))
# Out:
#     D   A   C   B
# 3   5   0   1   6
# 4  17   4   0  19
# 0  18  13   0  11
# 1   3  17  19   8
# 2  13  17   0   5

# %%
# ordenar columnas por valor en fila
display(frame.sort_values(by=1, axis=1, ascending=True))
# Out:
#     D   B   A   C
# 1   3   8  17  19
# 3   5   6   0   1
# 4  17  19   4   0
# 2  13   5  17   0
# 0  18  11  13   0

# %%
# ordenar por valor en columna y guardar cambios
frame.sort_values(by='A', ascending=False, inplace=True)
display(frame)
# Out:
#     D   A   C   B
# 1   3  17  19   8
# 2  13  17   0   5
# 0  18  13   0  11
# 4  17   4   0  19
# 3   5   0   1   6

# %% [markdown]
# #### Ranking
# - Construir un ranking de valores

# %%
display(frame)
# Out:
#     D   A   C   B
# 1   3  17  19   8
# 2  13  17   0   5
# 0  18  13   0  11
# 4  17   4   0  19
# 3   5   0   1   6

# %%
display(frame.rank(method='max', axis=1))
# Out:
#      D    A    C    B
# 1  1.0  3.0  4.0  2.0
# 2  3.0  4.0  1.0  2.0
# 0  4.0  3.0  1.0  2.0
# 4  3.0  2.0  1.0  4.0
# 3  3.0  1.0  2.0  4.0

# %%
# Imprimir, uno a uno, los valores de la columna 'C' de mayor a menor
for x in frame.sort_values(by='C', ascending=False)['C'].values:
    print(x)
# Out:
# 19
# 1
# 0
# 0
# 0

# %% [markdown]
# # Operaciones

# %% [markdown]
# Operaciones matemáticas entre objetos

# %%
matrixA = np.random.randint(100,size=(4,4))
matrixB = np.random.randint(100,size=(4,4))
frameA = pd.DataFrame(matrixA)
frameB = pd.DataFrame(matrixB)
display(frameA)
display(frameB)
# Out:
#     0   1   2   3
# 0  39  73  98  43
# 1   9  44  15  24
# 2  12  14  79  20
# 3  99  25  70  21
#     0   1   2   3
# 0  78  38  91  31
# 1  43  42  11  17
# 2  58  43  94  34
# 3  47  27   5  72

# %%
# a través de métodos u operadores
display(frameA + frameB == frameA.add(frameB))
display(frameA + frameB)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#      0    1    2   3
# 0  117  111  189  74
# 1   52   86   26  41
# 2   70   57  173  54
# 3  146   52   75  93

# %%
display(frameB - frameA == frameB.sub(frameA))
display(frameB - frameA)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#     0   1   2   3
# 0  39 -35  -7 -12
# 1  34  -2  -4  -7
# 2  46  29  15  14
# 3 -52   2 -65  51

# %%
# si los frames no son iguales, valor por defecto NaN
frameC = pd.DataFrame(np.random.randint(100,size=(3,3)))
display(frameA)
display(frameC)
display(frameC + frameA)
# Out:
#     0   1   2   3
# 0  39  73  98  43
# 1   9  44  15  24
# 2  12  14  79  20
# 3  99  25  70  21
#     0   1   2
# 0  24  50  97
# 1   5  17  15
# 2  93  48  19
#        0      1      2   3
# 0   63.0  123.0  195.0 NaN
# 1   14.0   61.0   30.0 NaN
# 2  105.0   62.0   98.0 NaN
# 3    NaN    NaN    NaN NaN

# %%
# se puede especificar el valor por defecto con el argumento fill_value
display(frameA.add(frameC, fill_value=0))
# Out:
#        0      1      2     3
# 0   63.0  123.0  195.0  43.0
# 1   14.0   61.0   30.0  24.0
# 2  105.0   62.0   98.0  20.0
# 3   99.0   25.0   70.0  21.0

# %% [markdown]
# Operadores aritméticos solo válidos en elementos aceptables

# %%
import pandas as pd

frameA = pd.DataFrame({0:[1,2], 1:[3,4]})
frameD = pd.DataFrame({0:[1,1], 1:[1,2]})

print(frameA - frameD)
# Out:
#    0  1
# 0  0  2
# 1  1  2

# %% [markdown]
# Operaciones entre Series y DataFrames

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
df = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(df)

display(df.iloc[0])
display(type(df.iloc[0]))
# uso común, averiguar la diferencia entre una fila y el resto
display(df - df.iloc[0])
display(df.sub(df.iloc[0], axis=1))
# Por columnas cómo se restaría
display(df.sub(df['A'], axis=0))
# Out:
#    A  B  C  D
# 0  9  7  1  9
# 1  2  8  5  8
# 2  7  0  9  9
# A    9
# B    7
# C    1
# D    9
# Name: 0, dtype: int32
# pandas.core.series.Series
#    A  B  C  D
# 0  0  0  0  0
# 1 -7  1  4 -1
# 2 -2 -7  8  0
#    A  B  C  D
# 0  0  0  0  0
# 1 -7  1  4 -1
# 2 -2 -7  8  0
#    A  B  C  D
# 0  0 -2 -8  0
# 1  0  6  3  6
# 2  0 -7  2  2

# %% [markdown]
# pandas se basa en NumPy, np operadores binarios y unarios son aceptables
#
# | Tipo | Operación | Descripción |
# |:---------|:-----|:-----|
# | Unario | *abs* | Valor absoluto de cada elemento |
# | | *sqrt* | Raíz cuadrada de cada elemento |
# | | *exp* | e^x, siendo x cad elemento |
# | | *log, log10, log2* | Logaritmos en distintas bases de cada elemento |
# | | *sign* | Retorna el signo de cada elemento (-1 para negativo, 0 o 1 para positivo) |
# | | *ceil* | Redondea cada elemento por arriba |
# | | *floor* | Redondea cada elemento por abajo |
# | | *isnan* | Retorna si cada elemento es Nan |
# | | *cos, sin, tan* | Operaciones trigonométricas en cada elemento |
# | | *arccos, arcsin, arctan* | Inversas de operaciones trigonométricas en cada elemento |
# | Binario | *add* | Suma de dos arrays |
# | | *substract* | Resta de dos arrays |
# | | *multiply* | Multiplicación de dos arrays |
# | | *divide* | División de dos arrays |
# | | *maximum, minimum* | Retorna el valor máximo/mínimo de cada pareja de elementos |
# | | *equal, not_equal* | Retorna la comparación (igual o no igual) de cada pareja de elementos |
# | | *greater, greater_equal, less, less_equal* | Retorna la comparación (>, >=, <, <= respectivamente) de cada pareja de elementos |

# %% [markdown]
# Aplicación de funciones a medida con lambda

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)

print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por columna
# Out:
#    A  B  C  D
# 0  2  3  2  3
# 1  0  5  0  0
# 2  9  3  9  4
# 0    1
# 1    5
# 2    6
# dtype: int32

# %%
def max_min(x):
    return x.max() - x.min()

print(frame.apply(max_min, axis = 0)) # diferencia por columna
# Out:
# A    9
# B    2
# C    9
# D    4
# dtype: int32

# %%
# diferencia entre min y max por fila (no columna)
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)

print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por fila
# Out:
#    A  B  C  D
# 0  8  6  9  1
# 1  7  1  6  6
# 2  1  6  8  7
# 0    8
# 1    6
# 2    7
# dtype: int32

# %% [markdown]
# # Estadística descriptiva
# - Análisis preliminar de los datos
# - Para Series y DataFrame
#
# | Operación | Descripción |
# |:----------|:------------|
# | count | Número de valores no NaN |
# | describe | Conjunto de estadísticas sumarias|
# | min, max | Valores mínimo y máximo |
# | argmin, argmax | Índices posicionales del valor mínimo y máximo |
# | idxmin, idxmax | Índices semánticos del valor mínimo y máximo |
# | sum | Suma de los elementos |
# | mean | Media de los elementos |
# | median | Mediana de los elementos |
# | mad | Desviación absoluta media del valor medio |
# | var | Varianza de los elementos |
# | std | Desviación estándar de los elementos |
# | cumsum | Suma acumulada de los elementos |
# | diff | Diferencia aritmética de los elementos |

# %%
diccionario = { "nombre" : ["Marisa","Laura","Manuel", "Carlos"], "edad" : [34,34,11, 30], 
               "puntos" : [98,12,98,np.nan], "genero": ["F", "F", "M", "M"] }
frame = pd.DataFrame(diccionario)
display(frame)
display(frame.describe()) # datos generales de elementos
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
#             edad     puntos
# count   4.000000   3.000000
# mean   27.250000  69.333333
# std    10.996211  49.652123
# min    11.000000  12.000000
# 25%    25.250000  55.000000
# 50%    32.000000  98.000000
# 75%    34.000000  98.000000
# max    34.000000  98.000000

# %%
# operadores básicos
print(frame.sum())

display(frame)
print(frame.sum(axis=1, numeric_only=True))
# Out:
# nombre    MarisaLauraManuelCarlos
# edad                          109
# puntos                      208.0
# genero                       FFMM
# dtype: object
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    34    12.0      F
# 2  Manuel    11    98.0      M
# 3  Carlos    30     NaN      M
# 0    132.0
# 1     46.0
# 2    109.0
# 3     30.0
# dtype: float64

# %%
frame.mean(numeric_only=True)
# Out:
# edad      27.250000
# puntos    69.333333
# dtype: float64

# %%
frame.cumsum()
# Out:
#                     nombre  edad  puntos genero
# 0                   Marisa    34    98.0      F
# 1              MarisaLaura    68   110.0     FF
# 2        MarisaLauraManuel    79   208.0    FFM
# 3  MarisaLauraManuelCarlos   109     NaN   FFMM

# %%
frame.count(axis=1)
# Out:
# 0    4
# 1    4
# 2    4
# 3    3
# dtype: int64

# %%
print(frame['edad'].std())
# Out:
# 10.996211468804457

# %%
frame['edad'].idxmax()
# Out:
# 0

# %%
frame['puntos'].idxmin()
# Out:
# 1

# %%
# frame con las filas con los valores maximos de una columna
print(frame['puntos'].max())

display(frame[frame['puntos'] == frame['puntos'].max()])
# Out:
# 98.0
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 2  Manuel    11    98.0      M

# %%
frame["ranking"] = frame["puntos"].rank(method='max')

# %%
display(frame)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0
# 2  Manuel    11    98.0      M      3.0
# 3  Carlos    30     NaN      M      NaN

# %% [markdown]
# ## Agregaciones

# %%
display(frame)
df = frame.groupby('genero').count()
display(df)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0
# 2  Manuel    11    98.0      M      3.0
# 3  Carlos    30     NaN      M      NaN
#         nombre  edad  puntos  ranking
# genero
# F            2     2       2        2
# M            2     2       1        1

# %%
# si es Nan descarta la fila
df = frame.groupby('puntos').count()
display(df)
# Out:
#         nombre  edad  genero  ranking
# puntos
# 12.0         1     1       1        1
# 98.0         2     2       2        2

# %%
display(frame.groupby('genero').mean(numeric_only=True))
# Out:
#         edad  puntos  ranking
# genero
# F       34.0    55.0      2.0
# M       20.5    98.0      3.0

# %%
display(frame.groupby('genero').max())
# Out:
#         nombre  edad  puntos  ranking
# genero
# F       Marisa    34    98.0      3.0
# M       Manuel    30    98.0      3.0

# %%
# funciones de agregación de varias columnas para obtener distintos estadísticos
display(frame.groupby('genero')[['edad', 'puntos']].aggregate(['min', 'mean', 'max']))
# Out:
#        edad           puntos
#         min  mean max    min  mean   max
# genero
# F        34  34.0  34   12.0  55.0  98.0
# M        11  20.5  30   98.0  98.0  98.0

# %%
# Filtrado de los datos en el que el conjunto no supera una media determinada 
def media(x):
    return x["edad"].mean() > 30

display(frame)
frame.groupby('genero').filter(media)
# Out:
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0
# 2  Manuel    11    98.0      M      3.0
# 3  Carlos    30     NaN      M      NaN
#    nombre  edad  puntos genero  ranking
# 0  Marisa    34    98.0      F      3.0
# 1   Laura    34    12.0      F      1.0

# %% [markdown]
# ## Correlaciones

# %% [markdown]
# pandas incluye métodos para analizar correlaciones
# - Relación matemática entre dos variables (-1 negativamente relacionadas, 1 positivamente relacionadas, 0 sin relación)
# - obj.corr(obj2) --> medida de correlación entre los datos de ambos objetos
# - https://blogs.oracle.com/ai-and-datascience/post/introduction-to-correlation

# %% [markdown]
# ### Ejemplo Fuel efficiency
# - https://archive.ics.uci.edu/ml/datasets/Auto+MPG

# %%
import pandas as pd
path = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

mpg_data = pd.read_csv(path, sep='\s+', header=None,
            names = ['mpg', 'cilindros', 'desplazamiento','potencia',
            'peso', 'aceleracion', 'año', 'origen', 'nombre'],
            na_values='?', engine='c')

# %%
display(mpg_data.sample(5))
# Out:
#       mpg  cilindros  desplazamiento  potencia    peso  aceleracion  año  \
# 26   10.0          8           307.0     200.0  4376.0         15.0   70
# 210  19.0          6           156.0     108.0  2930.0         15.5   76
# 3    16.0          8           304.0     150.0  3433.0         12.0   70
# 364  26.6          8           350.0     105.0  3725.0         19.0   81
# 152  19.0          6           225.0      95.0  3264.0         16.0   75
#
#      origen                   nombre
# 26        1                chevy c20
# 210       3           toyota mark ii
# 3         1            amc rebel sst
# 364       1    oldsmobile cutlass ls
# 152       1  plymouth valiant custom

# %%
display(mpg_data.describe(include='all'))
# Out:
#                mpg   cilindros  desplazamiento    potencia         peso  \
# count   398.000000  398.000000      398.000000  392.000000   398.000000
# unique         NaN         NaN             NaN         NaN          NaN
# top            NaN         NaN             NaN         NaN          NaN
# freq           NaN         NaN             NaN         NaN          NaN
# mean     23.514573    5.454774      193.425879  104.469388  2970.424623
# std       7.815984    1.701004      104.269838   38.491160   846.841774
# min       9.000000    3.000000       68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000      104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000      148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000      262.000000  126.000000  3608.000000
# max      46.600000    8.000000      455.000000  230.000000  5140.000000
#
#         aceleracion         año      origen      nombre
# count    398.000000  398.000000  398.000000         398
# unique          NaN         NaN         NaN         305
# top             NaN         NaN         NaN  ford pinto
# freq            NaN         NaN         NaN           6
# mean      15.568090   76.010050    1.572864         NaN
# std        2.757689    3.697627    0.802055         NaN
# min        8.000000   70.000000    1.000000         NaN
# 25%       13.825000   73.000000    1.000000         NaN
# 50%       15.500000   76.000000    1.000000         NaN
# 75%       17.175000   79.000000    2.000000         NaN
# max       24.800000   82.000000    3.000000         NaN

# %%
mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mpg             398 non-null    float64
#  1   cilindros       398 non-null    int64
#  2   desplazamiento  398 non-null    float64
#  3   potencia        392 non-null    float64
#  4   peso            398 non-null    float64
#  5   aceleracion     398 non-null    float64
#  6   año             398 non-null    int64
#  7   origen          398 non-null    int64
#  8   nombre          398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %% [markdown]
# ### Correlaciones entre valores

# %%
mpg_data['mpg'].corr(mpg_data['peso']) # + mpg = - peso
# Out:
# np.float64(-0.8317409332443352)

# %%
mpg_data['peso'].corr(mpg_data['aceleracion']) # + peso = - aceleracion
# Out:
# np.float64(-0.4174573199403932)

# %% [markdown]
# ### Correlaciones entre todos los valores

# %%
mpg_data.corr(numeric_only=True)
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             1.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   1.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        1.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  1.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  1.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
# año             0.579267  -0.348746       -0.370164 -0.416361 -0.306564
# origen          0.563450  -0.562543       -0.609409 -0.455171 -0.581024
#
#                 aceleracion       año    origen
# mpg                0.420289  0.579267  0.563450
# cilindros         -0.505419 -0.348746 -0.562543
# desplazamiento    -0.543684 -0.370164 -0.609409
# potencia          -0.689196 -0.416361 -0.455171
# peso              -0.417457 -0.306564 -0.581024
# aceleracion        1.000000  0.288137  0.205873
# año                0.288137  1.000000  0.180662
# origen             0.205873  0.180662  1.000000

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\ryzen\anaconda3\envs\machinelearning2026\lib\site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ryzen\anaconda3\envs\machinelearning2026\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ryzen\anaconda3\envs\machinelearning2026\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ryzen\anaconda3\envs\machinelearning2026\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 5.6 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.1 MB 7.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 8.6 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.1 MB 7.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 7.1 MB/s  0:00:01
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------------------------- ------------- 1.6/2.3 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 7.4 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# Downloading pillow-12.1.0-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    -------- ------------------------------- 1.6/7.0 MB 7.6 MB/s eta 0:00:01
#    -------------- ------------------------- 2.6/7.0 MB 6.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/7.0 MB 6.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.0 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 6.2 MB/s  0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.0 pyparsing-3.3.2

# %%
# representación gráfica matplotlib
import matplotlib.pyplot as plt

# %%
#año y origen no parecen correlacionables
#eliminar columnas de la correlacion
corr_data = mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True)
display(corr_data)
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             1.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   1.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        1.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  1.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  1.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
#
#                 aceleracion
# mpg                0.420289
# cilindros         -0.505419
# desplazamiento    -0.543684
# potencia          -0.689196
# peso              -0.417457
# aceleracion        1.000000

# %%
# representación gráfica
corr_data.style.background_gradient(cmap=plt.get_cmap('RdYlGn'), axis=1)
# Out:
# <style type="text/css">
# #T_f119f_row0_col0, #T_f119f_row1_col1, #T_f119f_row2_col2, #T_f119f_row3_col3, #T_f119f_row4_col4, #T_f119f_row5_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f119f_row0_col1, #T_f119f_row0_col3 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_f119f_row0_col2 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_f119f_row0_col4, #T_f119f_row1_col0, #T_f119f_row2_col0, #T_f119f_row3_col0, #T_f119f_row4_col0, #T_f119f_row5_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f119f_row0_col5 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_f119f_row1_col2 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_f119f_row1_col3, #T_f119f_row3_col1 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_f119f_row1_col4, #T_f119f_row2_col3, #T_f119f_row3_col2, #T_f119f_row4_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_f119f_row1_col5 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_f119f_row2_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_f119f_row2_col4, #T_f119f_row4_col2 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_f119f_row2_col5 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_f119f_row3_col4 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_f119f_row3_col5 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_f119f_row4_col3 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_f119f_row4_col5 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_f119f_row5_col0 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_f119f_row5_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_f119f_row5_col2 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_f119f_row5_col4 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f119f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f119f_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_f119f_level0_col1" class="col_heading level0 col1" >cilindros</th>
#       <th id="T_f119f_level0_col2" class="col_heading level0 col2" >desplazamiento</th>
#       <th id="T_f119f_level0_col3" class="col_heading level0 col3" >potencia</th>
#       <th id="T_f119f_level0_col4" class="col_heading level0 col4" >peso</th>
#       <th id="T_f119f_level0_col5" class="col_heading level0 col5" >aceleracion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f119f_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_f119f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f119f_row0_col1" class="data row0 col1" >-0.775396</td>
#       <td id="T_f119f_row0_col2" class="data row0 col2" >-0.804203</td>
#       <td id="T_f119f_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_f119f_row0_col4" class="data row0 col4" >-0.831741</td>
#       <td id="T_f119f_row0_col5" class="data row0 col5" >0.420289</td>
#     </tr>
#     <tr>
#       <th id="T_f119f_level0_row1" class="row_heading level0 row1" >cilindros</th>
#       <td id="T_f119f_row1_col0" class="data row1 col0" >-0.775396</td>
#       <td id="T_f119f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f119f_row1_col2" class="data row1 col2" >0.950721</td>
#       <td id="T_f119f_row1_col3" class="data row1 col3" >0.842983</td>
#       <td id="T_f119f_row1_col4" class="data row1 col4" >0.896017</td>
#       <td id="T_f119f_row1_col5" class="data row1 col5" >-0.505419</td>
#     </tr>
#     <tr>
#       <th id="T_f119f_level0_row2" class="row_heading level0 row2" >desplazamiento</th>
#       <td id="T_f119f_row2_col0" class="data row2 col0" >-0.804203</td>
#       <td id="T_f119f_row2_col1" class="data row2 col1" >0.950721</td>
#       <td id="T_f119f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f119f_row2_col3" class="data row2 col3" >0.897257</td>
#       <td id="T_f119f_row2_col4" class="data row2 col4" >0.932824</td>
#       <td id="T_f119f_row2_col5" class="data row2 col5" >-0.543684</td>
#     </tr>
#     <tr>
#       <th id="T_f119f_level0_row3" class="row_heading level0 row3" >potencia</th>
#       <td id="T_f119f_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_f119f_row3_col1" class="data row3 col1" >0.842983</td>
#       <td id="T_f119f_row3_col2" class="data row3 col2" >0.897257</td>
#       <td id="T_f119f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f119f_row3_col4" class="data row3 col4" >0.864538</td>
#       <td id="T_f119f_row3_col5" class="data row3 col5" >-0.689196</td>
#     </tr>
#     <tr>
#       <th id="T_f119f_level0_row4" class="row_heading level0 row4" >peso</th>
#       <td id="T_f119f_row4_col0" class="data row4 col0" >-0.831741</td>
#       <td id="T_f119f_row4_col1" class="data row4 col1" >0.896017</td>
#       <td id="T_f119f_row4_col2" class="data row4 col2" >0.932824</td>
#       <td id="T_f119f_row4_col3" class="data row4 col3" >0.864538</td>
#       <td id="T_f119f_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_f119f_row4_col5" class="data row4 col5" >-0.417457</td>
#     </tr>
#     <tr>
#       <th id="T_f119f_level0_row5" class="row_heading level0 row5" >aceleracion</th>
#       <td id="T_f119f_row5_col0" class="data row5 col0" >0.420289</td>
#       <td id="T_f119f_row5_col1" class="data row5 col1" >-0.505419</td>
#       <td id="T_f119f_row5_col2" class="data row5 col2" >-0.543684</td>
#       <td id="T_f119f_row5_col3" class="data row5 col3" >-0.689196</td>
#       <td id="T_f119f_row5_col4" class="data row5 col4" >-0.417457</td>
#       <td id="T_f119f_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# correlación más negativa
mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True).idxmin()
# Out:
# mpg                   peso
# cilindros              mpg
# desplazamiento         mpg
# potencia               mpg
# peso                   mpg
# aceleracion       potencia
# dtype: object

# %%
# correlación más positiva
mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True).idxmax()  #consigo misma....
# Out:
# mpg                          mpg
# cilindros              cilindros
# desplazamiento    desplazamiento
# potencia                potencia
# peso                        peso
# aceleracion          aceleracion
# dtype: object

# %%
import numpy as np

# tabla similar con las correlaciones más positivas (evitar parejas del mismo valor)
positive_corr = mpg_data.drop(['año','origen'],axis=1).corr(numeric_only=True)
np.fill_diagonal(positive_corr.values, 0)
display(positive_corr)
positive_corr.idxmax()
# Out:
#                      mpg  cilindros  desplazamiento  potencia      peso  \
# mpg             0.000000  -0.775396       -0.804203 -0.778427 -0.831741
# cilindros      -0.775396   0.000000        0.950721  0.842983  0.896017
# desplazamiento -0.804203   0.950721        0.000000  0.897257  0.932824
# potencia       -0.778427   0.842983        0.897257  0.000000  0.864538
# peso           -0.831741   0.896017        0.932824  0.864538  0.000000
# aceleracion     0.420289  -0.505419       -0.543684 -0.689196 -0.417457
#
#                 aceleracion
# mpg                0.420289
# cilindros         -0.505419
# desplazamiento    -0.543684
# potencia          -0.689196
# peso              -0.417457
# aceleracion        0.000000
# mpg                  aceleracion
# cilindros         desplazamiento
# desplazamiento         cilindros
# potencia          desplazamiento
# peso              desplazamiento
# aceleracion                  mpg
# dtype: object

# %%
positive_corr.style.background_gradient(cmap=plt.get_cmap('RdYlGn'), axis=1, vmin=-1.0, vmax=1.0)
# Out:
# <style type="text/css">
# #T_0c3b1_row0_col0, #T_0c3b1_row1_col1, #T_0c3b1_row2_col2, #T_0c3b1_row3_col3, #T_0c3b1_row4_col4, #T_0c3b1_row5_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_0c3b1_row0_col1, #T_0c3b1_row0_col3, #T_0c3b1_row1_col0, #T_0c3b1_row3_col0 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_0c3b1_row0_col2, #T_0c3b1_row2_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_0c3b1_row0_col4, #T_0c3b1_row4_col0 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_0c3b1_row0_col5, #T_0c3b1_row5_col0 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_0c3b1_row1_col2, #T_0c3b1_row2_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_0c3b1_row1_col3, #T_0c3b1_row3_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_0c3b1_row1_col4, #T_0c3b1_row2_col3, #T_0c3b1_row3_col2, #T_0c3b1_row4_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_0c3b1_row1_col5, #T_0c3b1_row5_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_0c3b1_row2_col4, #T_0c3b1_row4_col2 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_0c3b1_row2_col5, #T_0c3b1_row5_col2 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_0c3b1_row3_col4, #T_0c3b1_row4_col3 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_0c3b1_row3_col5, #T_0c3b1_row5_col3 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_0c3b1_row4_col5, #T_0c3b1_row5_col4 {
#   background-color: #fca85e;
#   color: #000000;
# }
# </style>
# <table id="T_0c3b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c3b1_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_0c3b1_level0_col1" class="col_heading level0 col1" >cilindros</th>
#       <th id="T_0c3b1_level0_col2" class="col_heading level0 col2" >desplazamiento</th>
#       <th id="T_0c3b1_level0_col3" class="col_heading level0 col3" >potencia</th>
#       <th id="T_0c3b1_level0_col4" class="col_heading level0 col4" >peso</th>
#       <th id="T_0c3b1_level0_col5" class="col_heading level0 col5" >aceleracion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c3b1_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_0c3b1_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_0c3b1_row0_col1" class="data row0 col1" >-0.775396</td>
#       <td id="T_0c3b1_row0_col2" class="data row0 col2" >-0.804203</td>
#       <td id="T_0c3b1_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_0c3b1_row0_col4" class="data row0 col4" >-0.831741</td>
#       <td id="T_0c3b1_row0_col5" class="data row0 col5" >0.420289</td>
#     </tr>
#     <tr>
#       <th id="T_0c3b1_level0_row1" class="row_heading level0 row1" >cilindros</th>
#       <td id="T_0c3b1_row1_col0" class="data row1 col0" >-0.775396</td>
#       <td id="T_0c3b1_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_0c3b1_row1_col2" class="data row1 col2" >0.950721</td>
#       <td id="T_0c3b1_row1_col3" class="data row1 col3" >0.842983</td>
#       <td id="T_0c3b1_row1_col4" class="data row1 col4" >0.896017</td>
#       <td id="T_0c3b1_row1_col5" class="data row1 col5" >-0.505419</td>
#     </tr>
#     <tr>
#       <th id="T_0c3b1_level0_row2" class="row_heading level0 row2" >desplazamiento</th>
#       <td id="T_0c3b1_row2_col0" class="data row2 col0" >-0.804203</td>
#       <td id="T_0c3b1_row2_col1" class="data row2 col1" >0.950721</td>
#       <td id="T_0c3b1_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_0c3b1_row2_col3" class="data row2 col3" >0.897257</td>
#       <td id="T_0c3b1_row2_col4" class="data row2 col4" >0.932824</td>
#       <td id="T_0c3b1_row2_col5" class="data row2 col5" >-0.543684</td>
#     </tr>
#     <tr>
#       <th id="T_0c3b1_level0_row3" class="row_heading level0 row3" >potencia</th>
#       <td id="T_0c3b1_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_0c3b1_row3_col1" class="data row3 col1" >0.842983</td>
#       <td id="T_0c3b1_row3_col2" class="data row3 col2" >0.897257</td>
#       <td id="T_0c3b1_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_0c3b1_row3_col4" class="data row3 col4" >0.864538</td>
#       <td id="T_0c3b1_row3_col5" class="data row3 col5" >-0.689196</td>
#     </tr>
#     <tr>
#       <th id="T_0c3b1_level0_row4" class="row_heading level0 row4" >peso</th>
#       <td id="T_0c3b1_row4_col0" class="data row4 col0" >-0.831741</td>
#       <td id="T_0c3b1_row4_col1" class="data row4 col1" >0.896017</td>
#       <td id="T_0c3b1_row4_col2" class="data row4 col2" >0.932824</td>
#       <td id="T_0c3b1_row4_col3" class="data row4 col3" >0.864538</td>
#       <td id="T_0c3b1_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_0c3b1_row4_col5" class="data row4 col5" >-0.417457</td>
#     </tr>
#     <tr>
#       <th id="T_0c3b1_level0_row5" class="row_heading level0 row5" >aceleracion</th>
#       <td id="T_0c3b1_row5_col0" class="data row5 col0" >0.420289</td>
#       <td id="T_0c3b1_row5_col1" class="data row5 col1" >-0.505419</td>
#       <td id="T_0c3b1_row5_col2" class="data row5 col2" >-0.543684</td>
#       <td id="T_0c3b1_row5_col3" class="data row5 col3" >-0.689196</td>
#       <td id="T_0c3b1_row5_col4" class="data row5 col4" >-0.417457</td>
#       <td id="T_0c3b1_row5_col5" class="data row5 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# - Ejercicios para practicar Pandas: https://github.com/ajcr/100-pandas-puzzles/blob/master/100-pandas-puzzles.ipynb

# %% [markdown]
# 2. Imprima la versión de pandas que se ha importado.

# %%
# Importamos pandas
import pandas as pd

# Mostrar qué versión tengo instalada
print("Versión de pandas:", pd.__version__)
# Out:
# Versión de pandas: 2.3.3

# %% [markdown]
# 4 Cree un DataFrame df a partir de estos datos del diccionario que tienen las etiquetas de índice.

# %%
# Importamos numpy y pandas
import numpy as np
import pandas as pd

# Datos de animales
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

# Etiquetas para las filas
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# Crear la tabla con los datos y las etiquetas
df = pd.DataFrame(data, index=labels)

# Mostrar la tabla
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# 6. Devuelve las primeras 3 filas del DataFrame df.

# %%
print(df.head(3))
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# 8. Seleccione los datos en las filas [3, 4, 8] y en las columnas ['animal', 'edad'].

# %%
# Importamos pandas
import pandas as pd

# Crear la tabla con datos de animales
tabla = pd.DataFrame({
    'animal': ['cat', 'dog', 'snake', 'cow', 'horse', 'sheep', 'lion', 'tiger', 'bear'],
    'age': [2, 5, 3, 7, 4, 6, 8, 9, 10]
})

# Seleccionar filas 3, 4 y 8, con las columnas animal y age
resultado = tabla.loc[[3, 4, 8], ['animal', 'age']]

# Mostrar el resultado
print(resultado)
# Out:
#   animal  age
# 3    cow    7
# 4  horse    4
# 8   bear   10

# %% [markdown]
# 10. Seleccione las filas donde falta la edad, es decir, es NaN.

# %%
df[df['age'].isna()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# 12. Seleccione las filas cuya edad esté entre 2 y 4 (inclusive).

# %%
df[df['age'].between(2, 4)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# 14. Calcula la suma de todas las visitas en gl (es decir, encuentra el número total de visitas).

# %%
# Traer pandas y numpy
import pandas as pd
import numpy as np

# Crear tabla con información de animales
tabla = pd.DataFrame({
    'animal': ['cat', 'dog', 'snake', 'cow', 'horse', 'sheep', 'lion', 'tiger', 'bear'],
    'age': [2, 5, 3, 7, 4, 6, 8, 9, 10],
    'visits': [1, 2, 3, 4, 5, 6, 7, 8, 9]
})

# Sumar todas las visitas
total_visitas = int(tabla['visits'].sum())

# Mostrar el total
print("Total de visitas:", total_visitas)
# Out:
# Total de visitas: 45

# %% [markdown]
# 16. Añada una nueva fila 'k' a df con los valores que elija para cada columna. Luego, elimine esa fila para devolver el DataFrame original.

# %%
# Agregar una nueva fila con índice 'k'
tabla.loc['k'] = ['elephant', 12, 5]
print("Tabla con la nueva fila:")
print(tabla)

# Eliminar la fila 'k' para volver a la tabla original
tabla = tabla.drop('k')
print("\nTabla sin la fila 'k':")
print(tabla)
# Out:
# Tabla con la nueva fila:
#      animal  age  visits
# 0       cat    2       1
# 1       dog    5       2
# 2     snake    3       3
# 3       cow    7       4
# 4     horse    4       5
# 5     sheep    6       6
# 6      lion    8       7
# 7     tiger    9       8
# 8      bear   10       9
# k  elephant   12       5
#
# Tabla sin la fila 'k':
#   animal  age  visits
# 0    cat    2       1
# 1    dog    5       2
# 2  snake    3       3
# 3    cow    7       4
# 4  horse    4       5
# 5  sheep    6       6
# 6   lion    8       7
# 7  tiger    9       8
# 8   bear   10       9

# %% [markdown]
# 18. Ordene df primero por los valores en la columna 'edad' en orden descendente, luego por el valor en la columna 'visitas' en orden ascendente (por lo que la fila i debe ser la primera y la fila d debe ser la última).

# %%
df = df.sort_values(by=['age', 'visits'], ascending=[False, True])
print(df)
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  2.0       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# 20. En la columna "animal", cambie las entradas "serpiente" a "pitón".

# %%
df['animal'] = df['animal'].replace('serpiente', 'pitón')
print(df)
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  2.0       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# ## GitHub
#
# https://github.com/alexis77710/machine-learning-introduccion.git
